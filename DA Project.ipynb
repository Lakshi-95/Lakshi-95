# %%
#Importing pandas
import pandas as pd

# %%
#Reading the data
df=pd.read_csv(r"C:\Users\Lakshi\Downloads\Crime_Data_from_2010_to_2019.csv")

# %%
#Now we begin exploring the data..Lets look at the columns of data
df.columns
# Out:
# Index(['DR_NO', 'Date Rptd', 'DATE OCC', 'TIME OCC', 'AREA ', 'AREA NAME',
#        'Rpt Dist No', 'Part 1-2', 'Crm Cd', 'Crm Cd Desc', 'Mocodes',
#        'Vict Age', 'Vict Sex', 'Vict Descent', 'Premis Cd', 'Premis Desc',
#        'Weapon Used Cd', 'Weapon Desc', 'Status', 'Status Desc', 'Crm Cd 1',
#        'Crm Cd 2', 'Crm Cd 3', 'Crm Cd 4', 'LOCATION', 'Cross Street', 'LAT',
#        'LON'],
#       dtype='object')

# %%
#Numbers of rows and columns
df.shape
# Out:
# (2139199, 28)

# %%
#Lets take 10K rows only(my laptop was working slow with this big data)
m=df.loc[0:10000]

# %%
#Lets look at 4 rows at the time
m.head(4)
# Out:
#       DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA   \
# 0   1307355  02/20/2010 12:00:00 AM  02/20/2010 12:00:00 AM      1350     13
# 1  11401303  09/13/2010 12:00:00 AM  09/12/2010 12:00:00 AM        45     14
# 2  70309629  08/09/2010 12:00:00 AM  08/09/2010 12:00:00 AM      1515     13
# 3  90631215  01/05/2010 12:00:00 AM  01/05/2010 12:00:00 AM       150      6
#
#    AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0     Newton         1385         2     900
# 1    Pacific         1485         2     740
# 2     Newton         1324         2     946
# 3  Hollywood          646         2     900
#
#                                          Crm Cd Desc  ... Status  \
# 0                           VIOLATION OF COURT ORDER  ...     AA
# 1  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...  ...     IC
# 2                          OTHER MISCELLANEOUS CRIME  ...     IC
# 3                           VIOLATION OF COURT ORDER  ...     IC
#
# ...

# %%
#To get last 5 rows of the data
df.tail()
#All are of 2019
# Out:
#              DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 2139194  190608903  03/28/2019 12:00:00 AM  03/28/2019 12:00:00 AM       400
# 2139195  190715222  08/15/2019 12:00:00 AM  08/14/2019 12:00:00 AM      1810
# 2139196  192004409  01/06/2019 12:00:00 AM  01/06/2019 12:00:00 AM      2100
# 2139197  191716777  10/17/2019 12:00:00 AM  10/16/2019 12:00:00 AM      1800
# 2139198  190805435  02/01/2019 12:00:00 AM  02/01/2019 12:00:00 AM      1615
#
#          AREA    AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 2139194      6   Hollywood          644         1     648
# 2139195      7    Wilshire          701         1     331
# 2139196     20     Olympic         2029         2     930
# 2139197     17  Devonshire         1795         1     420
# 2139198      8     West LA          852         1     330
#
#                                               Crm Cd Desc  ... Status  \
# 2139194                                             ARSON  ...     IC
# ...

# %%
#To calculate mean of victim age
m["Vict Age"].mean()
# Out:
# 32.164983501649836

# %%
#To check if we have data from 2020--I have sorted data on basis of year Date Rptd 
df.sort_values(["Date Rptd"]).tail()
#here crime is reported at later data that is 2020 but occured in 2019 or before
# Out:
#              DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 1934543  202018977  12/31/2020 12:00:00 AM  12/07/2019 12:00:00 AM         5
# 595065   211504022  12/31/2020 12:00:00 AM  02/06/2012 12:00:00 AM      1600
# 1816770  211604117  12/31/2020 12:00:00 AM  01/23/2018 12:00:00 AM      1735
# 1768259  210704018  12/31/2020 12:00:00 AM  08/01/2018 12:00:00 AM       100
# 393460   211504022  12/31/2020 12:00:00 AM  02/06/2012 12:00:00 AM      1600
#
#          AREA     AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 1934543     20      Olympic         2023         2     661
# 595065      15  N Hollywood         1505         1     310
# 1816770     16     Foothill         1637         2     354
# 1768259      7     Wilshire          773         2     649
# 393460      15  N Hollywood         1505         1     310
#
#                               Crm Cd Desc  ... Status  Status Desc Crm Cd 1  \
# ...

# %%
#lets us also look at date of occurence of crime
df.sort_values(['DATE OCC']).tail()
# Out:
#              DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 2113930  200404001  12/31/2019 12:00:00 AM  12/31/2019 12:00:00 AM      2315
# 1952974  200804089  01/03/2020 12:00:00 AM  12/31/2019 12:00:00 AM      1800
# 1952960  201208540  03/05/2020 12:00:00 AM  12/31/2019 12:00:00 AM      1159
# 2049591  201904135  12/31/2019 12:00:00 AM  12/31/2019 12:00:00 AM      1600
# 2012400  201704265  01/06/2020 12:00:00 AM  12/31/2019 12:00:00 AM      2000
#
#          AREA     AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 2113930      4   Hollenbeck          456         2     626
# 1952974      8      West LA          889         2     740
# 1952960     12  77th Street         1241         1     121
# 2049591     19      Mission         1954         1     330
# 2012400     17   Devonshire         1729         2     900
#
#                                                Crm Cd Desc  ... Status  \
# 2113930                  INTIMATE PARTNER - SIMPLE ASSAULT  ...     IC
# ...

# %%
df2=pd.read_csv(r"C:\Users\Lakshi\Downloads\Crime_Data_from_2020_to_Present.csv")

# %%
df2.columns
# Out:
# Index(['DR_NO', 'Date Rptd', 'DATE OCC', 'TIME OCC', 'AREA', 'AREA NAME',
#        'Rpt Dist No', 'Part 1-2', 'Crm Cd', 'Crm Cd Desc', 'Mocodes',
#        'Vict Age', 'Vict Sex', 'Vict Descent', 'Premis Cd', 'Premis Desc',
#        'Weapon Used Cd', 'Weapon Desc', 'Status', 'Status Desc', 'Crm Cd 1',
#        'Crm Cd 2', 'Crm Cd 3', 'Crm Cd 4', 'LOCATION', 'Cross Street', 'LAT',
#        'LON'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['DR_NO', 'Date Rptd', 'DATE OCC', 'TIME OCC', 'AREA ', 'AREA NAME',
#        'Rpt Dist No', 'Part 1-2', 'Crm Cd', 'Crm Cd Desc', 'Mocodes',
#        'Vict Age', 'Vict Sex', 'Vict Descent', 'Premis Cd', 'Premis Desc',
#        'Weapon Used Cd', 'Weapon Desc', 'Status', 'Status Desc', 'Crm Cd 1',
#        'Crm Cd 2', 'Crm Cd 3', 'Crm Cd 4', 'LOCATION', 'Cross Street', 'LAT',
#        'LON'],
#       dtype='object')

# %%
#Changing the column names for df2
df2.columns=['DR_NO', 'Date Rptd', 'DATE OCC', 'TIME OCC', 'AREA ', 'AREA NAME',
       'Rpt Dist No', 'Part 1-2', 'Crm Cd', 'Crm Cd Desc', 'Mocodes',
       'Vict Age', 'Vict Sex', 'Vict Descent', 'Premis Cd', 'Premis Desc',
       'Weapon Used Cd', 'Weapon Desc', 'Status', 'Status Desc', 'Crm Cd 1',
       'Crm Cd 2', 'Crm Cd 3', 'Crm Cd 4', 'LOCATION', 'Cross Street', 'LAT',
       'LON']

# %%
#Concatenating both the data sets
k=pd.concat([df,df2],ignore_index=True)

# %%
#We need to convert date rptd and date occ into date time.
#We have made date occ as the index of this dataset
k["Date Rptd"]=pd.to_datetime(k["Date Rptd"])
k["DATE OCC"]=pd.to_datetime(k["DATE OCC"])
k.set_index(["DATE OCC"],inplace=True)
k["count"]=1
k
k.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2495186 entries, 2010-02-20 to 2021-02-22
# Data columns (total 28 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   DR_NO           int64
#  1   Date Rptd       datetime64[ns]
#  2   TIME OCC        int64
#  3   AREA            int64
#  4   AREA NAME       object
#  5   Rpt Dist No     int64
#  6   Part 1-2        int64
#  7   Crm Cd          int64
#  8   Crm Cd Desc     object
#  9   Mocodes         object
#  10  Vict Age        int64
#  11  Vict Sex        object
#  12  Vict Descent    object
#  13  Premis Cd       float64
#  14  Premis Desc     object
#  15  Weapon Used Cd  float64
#  16  Weapon Desc     object
#  17  Status          object
#  18  Status Desc     object
#  19  Crm Cd 1        float64
#  20  Crm Cd 2        float64
#  21  Crm Cd 3        float64
#  22  Crm Cd 4        float64
#  23  LOCATION        object
#  24  Cross Street    object
#  25  LAT             float64
# ...

# %%
#To sum it yearwise
Yearwise_Count=k["count"].resample('Y').sum()
Yearwise_Count
# Out:
# DATE OCC
# 2010-12-31    209203
# 2011-12-31    105234
# 2012-12-31    297625
# 2013-12-31    192641
# 2014-12-31    110629
# 2015-12-31    320526
# 2016-12-31    225501
# 2017-12-31    231146
# 2018-12-31    228971
# 2019-12-31    217723
# 2020-12-31    197563
# 2021-12-31    158424
# Freq: A-DEC, Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,4))

Yearwise_Count.plot(kind='bar',title="crime occuring year-wise")
# Out:
# <AxesSubplot:title={'center':'crime occuring year-wise'}, xlabel='DATE OCC'>

# %%
k.isnull().sum()
#No missing values in crime code desc
# Out:
# DR_NO                   0
# Date Rptd               0
# TIME OCC                0
# AREA                    0
# AREA NAME               0
# Rpt Dist No             0
# Part 1-2                0
# Crm Cd                  0
# Crm Cd Desc             0
# Mocodes            279251
# Vict Age                0
# Vict Sex           245735
# Vict Descent       245783
# Premis Cd              45
# Premis Desc           296
# Weapon Used Cd    1647355
# Weapon Desc       1647356
# Status                  3
# Status Desc             0
# Crm Cd 1               13
# Crm Cd 2          2324854
# Crm Cd 3          2490568
# Crm Cd 4          2495053
# LOCATION                0
# Cross Street      2072527
# LAT                     0
# LON                     0
# count                   0
# dtype: int64

# %%
Num_Crimes = k['count']
Years = k['DATE OCC']
plt.bar(Num_Crimes,Years)
plt.xlabel("Year of Crime")
plt.ylabel("Number of crimes")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'DATE OCC'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-59-8227e89ff01c> in <module>
#       1 Num_Crimes = k['count']
# ...

# %%
k.tail()
# Out:
#                 DR_NO  Date Rptd  TIME OCC  AREA     AREA NAME  Rpt Dist No  \
# DATE OCC
# 2021-08-10  211512994 2021-08-10      1840     15  N Hollywood         1524
# 2021-03-19  211208872 2021-03-19      1105     12  77th Street         1218
# 2021-03-04  210506531 2021-03-04      2210      5       Harbor          564
# 2021-07-12  210312887 2021-07-12      1200      3    Southwest          363
# 2021-02-22  212005847 2021-02-22      1200     20      Olympic         2034
#
#             Part 1-2  Crm Cd                        Crm Cd Desc  \
# DATE OCC
# 2021-08-10         2     626  INTIMATE PARTNER - SIMPLE ASSAULT
# 2021-03-19         1     510                   VEHICLE - STOLEN
# 2021-03-04         2     434                 FALSE IMPRISONMENT
# 2021-07-12         1     350                      THEFT, PERSON
# 2021-02-22         1     510                   VEHICLE - STOLEN
#
#                                        Mocodes  ...   Status Desc Crm Cd 1  \
# ...

# %%
#To find unique values of crime code description
k["Crm Cd Desc"].unique()
# Out:
# array(['VIOLATION OF COURT ORDER',
#        'VANDALISM - FELONY ($400 & OVER, ALL CHURCH VANDALISMS)',
#        'OTHER MISCELLANEOUS CRIME', 'RAPE, ATTEMPTED',
#        'SHOPLIFTING - PETTY THEFT ($950 & UNDER)',
#        'BURGLARY FROM VEHICLE',
#        'ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT',
#        'THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LIVESTK,PROD',
#        'BATTERY - SIMPLE ASSAULT', 'ROBBERY', 'BOMB SCARE',
#        'CHILD NEGLECT (SEE 300 W.I.C.)',
#        'INTIMATE PARTNER - AGGRAVATED ASSAULT',
#        'INTIMATE PARTNER - SIMPLE ASSAULT',
#        'THEFT PLAIN - PETTY ($950 & UNDER)',
#        'CRIMINAL THREATS - NO WEAPON DISPLAYED', 'ATTEMPTED ROBBERY',
#        'VANDALISM - MISDEAMEANOR ($399 OR UNDER)', 'BURGLARY', 'ARSON',
#        'RAPE, FORCIBLE', 'BRANDISH WEAPON',
#        'THROWING OBJECT AT MOVING VEHICLE',
#        'SHOPLIFTING-GRAND THEFT ($950.01 & OVER)',
#        'CHILD ABUSE (PHYSICAL) - SIMPLE ASSAULT',
# ...

# %%
#To count the number of each type
pd.value_counts(k['Crm Cd Desc'])
# Out:
# BATTERY - SIMPLE ASSAULT                                   220277
# VEHICLE - STOLEN                                           200584
# BURGLARY FROM VEHICLE                                      186923
# THEFT PLAIN - PETTY ($950 & UNDER)                         170575
# BURGLARY                                                   170178
#                                                             ...
# BLOCKING DOOR INDUCTION CENTER                                  3
# TRAIN WRECKING                                                  2
# DRUNK ROLL - ATTEMPT                                            1
# FIREARMS EMERGENCY PROTECTIVE ORDER (FIREARMS EPO)              1
# FIREARMS TEMPORARY RESTRAINING ORDER (TEMP FIREARMS RO)         1
# Name: Crm Cd Desc, Length: 143, dtype: int64

# %%
#Lets see the distribution of crimes in each and if it has changed post covid--stacked bargraph

# %%
import seaborn as sns

# %%
sns.countplot(k['Crm Cd Desc'].tail(10))
# Out:
# C:\Users\Lakshi\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Crm Cd Desc', ylabel='count'>

# %%
#Number of crimes on each date
#k.groupby(['Crm Cd Desc','DATE OCC'])["count"].sum()
# Out:
# Crm Cd Desc                 DATE OCC
# ABORTION/ILLEGAL            2013-02-27    1
#                             2013-03-22    1
#                             2013-08-08    1
#                             2017-10-28    1
#                             2018-01-19    1
#                                          ..
# WEAPONS POSSESSION/BOMBING  2021-06-15    2
#                             2021-06-25    1
#                             2021-06-30    1
#                             2021-07-30    1
#                             2021-08-09    1
# Name: count, Length: 223351, dtype: int64

# %%
#Extracting year from time stamp
import re

# %%
k['DATE OCC'].str.extract(r'(\d{4})')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'DATE OCC'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-43-f8cf7fdb4573> in <module>
# ...

# %%
k
# Out:
#                 DR_NO  Date Rptd  TIME OCC  AREA     AREA NAME  Rpt Dist No  \
# DATE OCC
# 2010-02-20    1307355 2010-02-20      1350     13       Newton         1385
# 2010-09-12   11401303 2010-09-13        45     14      Pacific         1485
# 2010-08-09   70309629 2010-08-09      1515     13       Newton         1324
# 2010-01-05   90631215 2010-01-05       150      6    Hollywood          646
# 2010-01-02  100100501 2010-01-03      2100      1      Central          176
# ...               ...        ...       ...    ...          ...          ...
# 2021-08-10  211512994 2021-08-10      1840     15  N Hollywood         1524
# 2021-03-19  211208872 2021-03-19      1105     12  77th Street         1218
# 2021-03-04  210506531 2021-03-04      2210      5       Harbor          564
# 2021-07-12  210312887 2021-07-12      1200      3    Southwest          363
# 2021-02-22  212005847 2021-02-22      1200     20      Olympic         2034
#
#             Part 1-2  Crm Cd  \
# DATE OCC
# ...
